# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaos-19/practical_deep_learning_for_coders/blob/main/model_deployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! [ -e /content ] && pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
from fastai.vision.all import *
from fastai.vision.widgets import *

# %%
im = PILImage.create('images.jfif')
im.thumbnail((200,200))
im

# %%
#| export
learn = load_learner('model.pkl')

# %%
learn.predict(im)

# %%
categories = learn.dls.vocab

def classify_image(img):
    pred,pred_idx,probs = learn.predict(img)
    return dict(zip(categories, map(float,probs)))

# %%
classify_image(im)

# %%
# !pip install gradio
from gradio import *

# %%
image = gr.Image(width=192, height=192)
label = gr.Label()
examples = ['images.jfif']

intf = gr.Interface(fn=classify_image, inputs=image, outputs=label, examples=examples)
intf.launch(inline=False)
